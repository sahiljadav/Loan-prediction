# %% [markdown]
# ## Step 1
# # Import Libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2
# # Preveiw data

# %%
data = pd.read_csv('Loan_default.csv')
data.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
# 3      Full-time       Married          No            No    Business
# 4     Unemployed      Divorced          No           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1
# 3          No        0
# 4          No        0

# %%
data.tail()
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 255342               4         14.11        12      0.85   Bachelor's
# 255343               2         11.55        24      0.21  High School
# 255344               3          5.29        60      0.50  High School
# 255345               1         20.90        48      0.44  High School
# 255346               2          6.73        12      0.48   Bachelor's
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 255342      Full-time       Married          No            No       Other
# 255343      Part-time      Divorced          No            No        Home
# 255344  Self-employed       Married         Yes           Yes        Auto
# 255345      Part-time        Single         Yes           Yes       Other
# 255346     Unemployed      Divorced         Yes            No   Education
#
#        HasCoSigner  Default
# 255342          No        0
# 255343          No        1
# 255344         Yes        0
# 255345          No        0
# 255346         Yes        0

# %% [markdown]
# ## Step 3
# # Check Datatype

# %%
data.dtypes
# Out:
# LoanID             object
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education          object
# EmploymentType     object
# MaritalStatus      object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# HasCoSigner        object
# Default             int64
# dtype: object

# %% [markdown]
# ## Step 4
# # check Dataset null values

# %%
data.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %% [markdown]
# ## Step 5
#
# # Dataset Shape

# %%
data.shape
# Out:
# (255347, 18)

# %% [markdown]
# ## Step 6
# #  Dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
#  16  HasCoSigner     255347 non-null  object
#  17  Default         255347 non-null  int64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 35.1+ MB

# %% [markdown]
# ## Step 7
# #  Statistical Summary

# %%
data.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# 25%         30.000000        2.000000       7.770000      24.000000
# 50%         60.000000        2.000000      13.460000      36.000000
# 75%         90.000000        3.000000      19.250000      48.000000
# max        119.000000        4.000000      25.000000      60.000000
#
#             DTIRatio        Default
# count  255347.000000  255347.000000
# mean        0.500212       0.116128
# std         0.230917       0.320379
# min         0.100000       0.000000
# 25%         0.300000       0.000000
# 50%         0.500000       0.000000
# 75%         0.700000       0.000000
# max         0.900000       1.000000

# %% [markdown]
# ## Step 8
# # Remove Irrelevant Columns

# %%
data.drop(['LoanID'], axis=1, inplace=True)

# %% [markdown]
# ## Step 9
# # Identify Target Variable Distribution

# %%
data['Default'].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %% [markdown]
# ## Step 10
# # Visualize Class Distribution

# %%
sns.countplot(x='Default', data=data)
plt.show()

# %% [markdown]
# ## Step 11
# # Separate Numerical and Categorical Columns

# %%
num_cols = data.select_dtypes(include=['int64','float64']).columns
cat_cols = data.select_dtypes(include=['object']).columns

# %% [markdown]
# ## Step 12
# # Outlier Detection Using Z-Score

# %%
from scipy.stats import zscore
z_scores = np.abs(zscore(data[num_cols]))

Q1 = data[num_cols].quantile(0.25)
Q3 = data[num_cols].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# Age                   25.00
# Income             67393.50
# LoanAmount        122829.00
# CreditScore          275.00
# MonthsEmployed        60.00
# NumCreditLines         1.00
# InterestRate          11.48
# LoanTerm              24.00
# DTIRatio               0.40
# Default                0.00
# dtype: float64

# %% [markdown]
# ## Step 13
# # Encoding Binary Categorical Variables

# %%
binary_cols = ['HasMortgage','HasDependents','HasCoSigner']
for col in binary_cols:
 data[col] = data[col].map({'Yes':1,'No':0})

# %% [markdown]
# ## Step 14
# # Find numeric Column for Correlation

# %%
num_df = data.select_dtypes(include=['int64', 'float64'])

# %% [markdown]
# ## Step 15
# # Compute Correlation Matrix

# %%
corr_matrix = num_df.corr()
corr_matrix
# Out:
#                      Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# Age             1.000000 -0.001244   -0.002213    -0.000548       -0.000341
# Income         -0.001244  1.000000   -0.000865    -0.001430        0.002675
# LoanAmount     -0.002213 -0.000865    1.000000     0.001261        0.002817
# CreditScore    -0.000548 -0.001430    0.001261     1.000000        0.000613
# MonthsEmployed -0.000341  0.002675    0.002817     0.000613        1.000000
# NumCreditLines -0.000890 -0.002016    0.000794     0.000016        0.001267
# InterestRate   -0.001127 -0.002303   -0.002291     0.000436        0.000096
# LoanTerm        0.000263 -0.000998    0.002538     0.001130       -0.001166
# DTIRatio       -0.004689  0.000205    0.001122    -0.001039        0.001765
# HasMortgage     0.000035 -0.000945   -0.000801     0.001728        0.000210
# HasDependents   0.000710 -0.001570    0.000139    -0.003018        0.001450
# HasCoSigner    -0.002918 -0.003524   -0.001848    -0.002755        0.001045
# Default        -0.167783 -0.099119    0.086659    -0.034166       -0.097374
#
#                 NumCreditLines  InterestRate  LoanTerm  DTIRatio  HasMortgage  \
# Age                  -0.000890     -0.001127  0.000263 -0.004689     0.000035
# Income               -0.002016     -0.002303 -0.000998  0.000205    -0.000945
# LoanAmount            0.000794     -0.002291  0.002538  0.001122    -0.000801
# CreditScore           0.000016      0.000436  0.001130 -0.001039     0.001728
# MonthsEmployed        0.001267      0.000096 -0.001166  0.001765     0.000210
# NumCreditLines        1.000000     -0.000297 -0.000226 -0.000586    -0.001744
# InterestRate         -0.000297      1.000000  0.000892  0.000575    -0.000424
# LoanTerm             -0.000226      0.000892  1.000000  0.002273     0.001775
# DTIRatio             -0.000586      0.000575  0.002273  1.000000     0.000231
# HasMortgage          -0.001744     -0.000424  0.001775  0.000231     1.000000
# HasDependents        -0.001895     -0.000243  0.002417  0.001492     0.000067
# HasCoSigner           0.002105     -0.003991 -0.001166  0.000373    -0.003529
# Default               0.028330      0.131273  0.000545  0.019236    -0.022856
#
#                 HasDependents  HasCoSigner   Default
# Age                  0.000710    -0.002918 -0.167783
# Income              -0.001570    -0.003524 -0.099119
# LoanAmount           0.000139    -0.001848  0.086659
# CreditScore         -0.003018    -0.002755 -0.034166
# MonthsEmployed       0.001450     0.001045 -0.097374
# NumCreditLines      -0.001895     0.002105  0.028330
# InterestRate        -0.000243    -0.003991  0.131273
# LoanTerm             0.002417    -0.001166  0.000545
# DTIRatio             0.001492     0.000373  0.019236
# HasMortgage          0.000067    -0.003529 -0.022856
# HasDependents        1.000000     0.001602 -0.034678
# HasCoSigner          0.001602     1.000000 -0.039109
# Default             -0.034678    -0.039109  1.000000

# %% [markdown]
# ## Step 16
# # Visualize Correlation Matrix

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Step 17
# # Simple Scatter Plot (Icome vs Loan Amount)

# %%
# first 1000 record

plt.figure(figsize=(8,6))
plt.scatter(data['Income'][:1000], data['LoanAmount'][:1000])
plt.xlabel("Income")
plt.ylabel("Loan Amount")
plt.title("Income vs Loan Amount")
plt.show()

# %% [markdown]
# ## Step 18
# # Line Graph

# %%
df_sorted = data.sort_values(by='Income')

# first 500 record
plt.figure(figsize=(8,6))
plt.plot(df_sorted['Income'][:500], df_sorted['LoanAmount'][:500])
plt.xlabel("Income")
plt.ylabel("Loan Amount")
plt.title("Loan Amount Trend by Income")
plt.show()

# %% [markdown]
# ## Step 19
# # Feature Distribution Analysis

# %%
data.hist(figsize=(15,10))

plt.show()

# %% [markdown]
# ## Step 20
# # Income Distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['Income'], bins=40, kde=True)
plt.xlabel("Income")
plt.title("Income Distribution")
plt.show()

# %% [markdown]
# ## Step 21
# # Loan Amount Distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(data['LoanAmount'], bins=20, kde=True)
plt.xlabel("Loan Amount")
plt.title("Loan Amount Distribution")
plt.show()

# %% [markdown]
# ## Step 22
# # Box Plot (Credit Score vs Loan Default)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Default', y='CreditScore', data=data)
plt.xlabel("Loan Default")
plt.ylabel("Credit Score")
plt.title("Credit Score vs Loan Default")
plt.show()

# %% [markdown]
# ## Step 23
# # New Dataset Creation

# %%
data.to_csv("loan_default_preprocessed.csv", index=False)
